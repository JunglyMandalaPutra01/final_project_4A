# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
rcParams['figure.figsize'] = (10,7)
rcParams['lines.linewidth'] = 2.5
rcParams['xtick.labelsize'] = 'x-large'
rcParams['ytick.labelsize'] = 'x-large'

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
display(df)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df[df.duplicated(subset='CustomerId', keep = False)]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### Hasil Observasi
# Pada Dataset semua tipe data pada setiap kolom sudah sesuai dengan isinya, terdapat tiga tipe data yang ada pada dataset yaitu tipe data integer, float dan object. <br>
# Dalam dataset ini juga tidak memiliki data kosong atau null pada setiap kolomnya dan tidak ditemukan data duplikat berdasarkan Customer Id serta tidak ada nilai summary yang aneh.<br>
# Pada kolom 'CreditScore' memiliki rata-rata sekitar 650, dengan nilai minimum 350 dan maksimum 850. Kolom 'Age' memiliki rata-rata sekitar 38 tahun, dengan nilai minimum 18 tahun dan maksimum 92 tahun. Kolom 'Balance' memiliki rata-rata sekitar 76,486, dengan nilai minimum 0 dan maksimum 250,898. 'NumOfProducts' memiliki rata-rata sekitar 1.53, dengan nilai minimum 1 dan maksimum 4. Kolom 'Exited' adalah kolom target yang memiliki rata-rata sekitar 0.204, yang berarti sekitar 20.4% pelanggan berhenti (memiliki nilai 1) berdasarkan data ini.

# %% [markdown]
# # Univariate Analysis
# Gunakan visualisasi untuk melihat distribusi masing-masing kolom (feature maupun
# target).

# %%
categ = ['Gender', 'NumOfProducts', 'Geography']
nums = ['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary']
str = ['Surname', 'Geography']
boolean = ['HasCrCard', 'IsActiveMember','Exited']

# %% [markdown]
# ### Visualisasi Data Numerik

# %%
for i in range(0, len(nums)):
    plt.subplot(1, len(nums), i+1)
    sns.boxplot(y=df[nums[i]], color='skyblue', orient='v')
    plt.tight_layout()

# %% [markdown]
# Pada visualisasi kolom Age terlihat bahwa terdapat nilai Outlier sehingga tipe distribusinya Positively skewed dan juga dapat dilihat bahwa umur nasabah paling banyak berkisar antara 30 sampai 40 tahun atau usia dewasalah yang paling dominan.<br>

# %%
plt.figure(figsize=(12, 5))
for i in range(0, len(nums)):
    plt.subplot(2, len(nums), i+1)
    sns.distplot(df[nums[i]], color='green')
    plt.tight_layout()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13748\946389498.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[nums[i]], color='green')
# C:\Users\asus\AppData\Local\Temp\ipykernel_13748\946389498.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# Pada kolom CreditScore memiliki nilai Outlier sehingga tipe distibusinya adalah negatively skewed dan CreditScore yang paling banyak berkisar antara 580 sampai 720 serta memiliki lonjakan sedikit pada data yang turun.<br>

# %%
for i in range(0, len(nums)):
    plt.subplot(1, len(nums), i+1)
    sns.violinplot(y=df[nums[i]], color='skyblue', orient='v')
    plt.tight_layout()

# %% [markdown]
# Distibusi dari kolom Tenure terlihat normal dan tidak memiliki outlier.<br>
# Pada kolom Balance terdapat nilai 0 yang paling mendominasi dari pada jumlah yang lain dan memiliki lonjakan data yang menurun serta naik.<br>
# Distibusi dari EstimatedSalary nasabah itu normal dan dapat dilihat bahwa ada EstimatedSalary dari nasabah yang 0 atau tidak ada.

# %% [markdown]
# ### Visualisasi Data Kategori

# %%
for i in range(0, len(categ)):
    plt.subplot(1, len(categ), 1+i)
    sns.countplot(x=df[categ[i]], color =  'skyblue')
    plt.tight_layout()

# %% [markdown]
# Nasabah yang laki-laki lebih mendominasi dibandingkan dengan nasabah Perempuan.<br>
# NumOfProducts 1 paling mendominasi dengan jumlah nasabah yang menggunakannya lebih dari 500 nasabah dan yang paling sedikit itu NumOfProducts 4. Serta 50% dari seluruh nasabah berasal dari France.<br>

# %% [markdown]
# ### Visulisasi Data Booelan

# %%
for i in range(0, len(boolean)):
    plt.subplot(1, len(boolean), 1+i)
    sns.countplot(x=df[boolean[i]], color =  'skyblue')
    plt.tight_layout()

# %% [markdown]
# Pada kolom HasCrChard, banyak nasabah yang sudah memiliki kartu kredit.<br>
# Pada kolom IsActiveMember dapat dilihat bahwa perbedaan dari Nasabah aktif dan tidak itu sangat sedikit yaitu kisaran 400an saja, namun masih tetap didominasi oleh Nasabah aktif.<br>
# Pada kolom Exited, Hampir 80% jumlah nasabah yang masih stay dan 20% selain itu adalah nasabah yang meninggalkan Bank.<br>
#
# Pada saat melakukan data pre-processing, harus memastikan data tidak memiliki outlier yang tidak normal, baris yang kosong atau tidak digunakan dihapus dan memiliki nilai 0 harus di perbaiki.

# %% [markdown]
# ## Multivariate Analysis

# %%
df.corr()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13748\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# ...

# %%
sns.heatmap(df.corr(), annot=True, cmap="Blues")
plt.title('Heatmap Korelasi antara Fitur dan Label')

plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13748\3160457217.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="Blues")

# %%
label = df['Exited']
numerik = df[['CreditScore', 'Age', 'EstimatedSalary', 'Tenure', 'Balance']]
numerik2 = df[['CreditScore', 'Age', 'EstimatedSalary', 'Tenure', 'Balance', 'Exited']]
kategori = df[['Gender', 'NumOfProducts', 'Geography']]

# %% [markdown]
# ### Korelasi antara Feature Numerik dan Label Menggunakan metode Point-biserial

# %%
from scipy import stats

correlations = []

for col in fitur.columns:
    r, p = stats.pointbiserialr(label, numerik[col])
    correlations.append(r)

plt.figure(figsize=(10, 6))
plt.scatter(numerik.columns, correlations, color='b', marker='o')
plt.title('Korelasi Point-Biserial antara Exited dan Fitur Numerik', fontsize = 15)
plt.xlabel('Fitur')
plt.ylabel('Korelasi Point-Biserial (r)')
plt.grid(True)
plt.show()

# %% [markdown]
# Terdapat korelasi positif dari kolom Exited dengan kolom Age sebesar 0,29 > 0,05 yang berarti semakin tua umur customer maka akan semakin rentan untuk Churn. Selain itu, juga terdapat korelasi positif antara kolom Balance dan Exited sebesar 0,12 > 0,05 yang berarti semakin besar nilai Balance customer, maka akan semakin rentan untuk churn. Namun, korelasi dari kedua kasus tersebut tidak kuat (< 0,7)

# %%
fig = plt.figure(figsize=(15, 15))
for i in range(0, len(nums)): 
    ax = fig.add_subplot(3, 3, i+1) 
    sns.stripplot(ax=ax, data=df, x='Exited', y=nums[i]) 
    plt.tight_layout()

# %% [markdown]
# ### Korelasi antara Feature kategori dan Label mengunakan Kendall Tau

# %%
from scipy.stats import kendalltau

gender, _ = kendalltau(df['Exited'], df['Gender'])
geo, _ = kendalltau(df['Exited'], df['Geography'])
prod, _ = kendalltau(df['Exited'], df['NumOfProducts'])

plt.subplot(131)
plt.scatter(df['Exited'], df['Gender'])
plt.title(f'Kendall Tau: {gender:.2f}')
plt.xlabel('Exited')
plt.ylabel('Gender')

plt.subplot(132)
plt.scatter(df['Exited'], df['Geography'])
plt.title(f'Kendall Tau: {geo:.2f}')
plt.xlabel('Exited')
plt.ylabel('Geography')

plt.subplot(133)
plt.scatter(df['Exited'], df['NumOfProducts'])
plt.title(f'Kendall Tau: {prod:.2f}')
plt.xlabel('Exited')
plt.ylabel('NumOfProducts')

plt.tight_layout()
plt.show()

# %% [markdown]
# Korelasi antar masing-masing feature dan label tidak semuanya memiliki korelasi yang bearti terhadap label yaitu Exited. Selain itu hampir semua feature memiliki korelasi yang kuat terhadap label, namun ada beberapa feature yang harus dipertahankan seperti feature CreditScore, Age, Tenure, Balance dan EstimatedSalary.<br>

# %%
sns.pairplot(numerik, diag_kind='kde')

# %% [markdown]
# Korelasi antar feature sangat beragam, ada yang memiliki korelasi yang kuat dan ada juga yang tidak memiliki korelasi yang kuat. Berikut ini kolom-kolom yang memiliki korelasi yang paling kuat yaitu feature Age dan Balance dengan label Exited, feature Age dengan IsActiveMember serta ada beberapa feature yang memiliki korelasi tidak kuat seperti CustomerId dengan NumOfProducts dan EstimatedSalary, HasCrChard dan Tenure. Sedangkan untuk feature yang paling rendah tingkat korelasinya adalah feature NumOfProducts dengan Balance dan feature IsActiveMember dengan Exited. Pada semua feature tidak terlihat memiliki pola yang menarik. <br>
# "Tenure" memiliki korelasi yang kuat dengan "Exited," menunjukkan bahwa lamanya waktu yang pelanggan habiskan dengan layanan memiliki pengaruh signifikan terhadap kecenderungan keluar. Ini dapat mengindikasikan bahwa pelanggan yang telah menggunakan layanan untuk jangka waktu yang lebih lama lebih cenderung tetap sebagai pelanggan setia.
# "Balance" juga memiliki korelasi yang kuat dengan "Exited," menunjukkan bahwa saldo dalam akun pelanggan memiliki pengaruh signifikan terhadap kecenderungan keluar. Pelanggan dengan saldo yang tinggi mungkin kurang cenderung keluar.
# "EstimatedSalary" memiliki korelasi dengan "Exited," meskipun tidak sekuat yang lain. Ini menunjukkan bahwa estimasi gaji pelanggan juga memengaruhi kecenderungan keluar, meskipun korelasinya tidak begitu kuat.

# %% [markdown]
# ## Business Insight

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Exited", y="Age", data=df)
plt.title("Perbandingan Usia nasabah yang churn dan stay")
plt.xlabel("Status nasabah", fontsize = 12)
plt.ylabel("Usia", fontsize = 12)
sns.despine()
plt.show()

# %% [markdown]
# Insight = Usia nasabah yang paling banyak Churn termasuk ke dalam kelompok usia dewasa sampai lansia dengan kisaran umur antara 37 - 50 tahun. Sedangkan yang masih tetap stay lebih banyak nasabah dalam usia dewasa yaitu berkisar antara 31 sampai 41 tahun.<br>
# Rekomendasi = Tim produk dan marketing harus berkolaborasi untuk membuat dan menawarkan produk atau layanan yang sesuai dengan kebutuhan kelompok usia dewasa sampai lansia.

# %%
sns.set(style="whitegrid")
sns.countplot(x="Tenure", hue="Exited", data=df)
plt.title("Distribusi Nasabah Churn berdasarkan Tenure", fontsize = 15)
plt.xlabel("Tenure")
plt.ylabel("Jumlah Nasabah")
sns.despine()
plt.show()

# %% [markdown]
# Insight = Nasabah yang memiliki jumlah Tenure 1 cenderung banyak melakukan churn dibandingkan dengan nasabah dengan jumlah Tenure yang lain dan terdapat 210 nasabah yang melakukan Churn.<br>
# Rekomendasi = Pihak Bank harus meningkatkan pelayanan khusus terhadap nasabah yang memiliki tenure dan dapat memberikan promo tertentu agar meningkatkan loyalitas nasabah.

# %%
sns.set(style="whitegrid")
sns.countplot(x="Gender", hue="Exited", data=df)
plt.title("Distribusi Nasabah Churn berdasarkan Jenis Kelamin", fontsize = 15)
plt.xlabel("Jenis Kelamin")
plt.ylabel("Jumlah Nasabah")
sns.despine()
plt.show()

# %% [markdown]
# Insight = Lebih banyak nasabah wanita yang melakukan churn dibandingkan nasabah laki-laki.<br>
# Rekomendasi = Pihak Bank harus memperhatikan program khusus bagi setiap nasabah terutama wanita dengan memberikan produk yang sesuai dengan kesukaan wanita dan juga membuat produk untuk menurunkan tingkat nasabah pria yang churn dengan memberikan promo atau layanan khusus bagi setiap nasabah sesuai jenis kelamin.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Balance", hue="Exited", bins=30, kde=True)
plt.title("Distribusi Nasabah Churn berdasarkan Saldo", fontsize = 15)
plt.xlabel("Saldo Rata-rata")
plt.ylabel("Jumlah")
sns.despine()
plt.show()

# %% [markdown]
# Insight = Nasabah yang churn paling banyak tidak memiliki Balance.<br>
# Rekomendasi = Pihak Bank harus mempertimbangkan untuk meningkatkan layanan atau insentif dan memberikan promosi khusus bagi nasabah yang tidak memiliki Balance.

# %%
sns.set(style="whitegrid")
sns.countplot(x="Geography", hue="Exited", data=df)
plt.title('Distribusi Nasabah Churn berdasarkan Geography', fontsize = 15)
plt.xlabel("Negara Asal")
plt.ylabel("Jumlah Nasabah")
sns.despine()
plt.show()

# %% [markdown]
# Insight = Nasabah yang Churn lebih banyak  berasal dari France meskipun tidak terlalu jauh berbeda dari banyaknya nasabah yang Churn dari Germany.<br>
# Rekomendasi = Pihak Bank harus menjaga kepercayaan dari setiap nasabah yang bersalah dari semua negara yang ada dengan memberikan pelayanan dan produk khusus yang banyak diminati oleh masing-masing negara. Dapat juga dilakukan promo khusus bagi setiap negara agar tingkat nasabah loyal menjadi tinggi.

# %% [markdown]
# ## Git
# ### Bukti sudah upload di GitHub
# ![image.png](attachment:2e6cf97f-e2e2-40bd-a171-ee989cfc06cf.png)
